# %% [markdown]
# **This is a introduction of you and the favorite holiday spot**

# %%
name = input("please enter your name: ")
# Out:
# please enter your name: John

# %%
print("the user's name is", name)
# Out:
# the user's name is John

# %% [markdown]
# ![Lab.webp](attachment:Lab.webp)

# %% [markdown]
# ![hhhh.jpeg](attachment:hhhh.jpeg)

# %% [markdown]
# Three things he likes to do:
# - jugging
# - reading
# - swimming

# %% [markdown]
# Link = [https://www.youtube.com/watch?v=gm6tNK_iOHs]
